# %%
import matplotlib.pyplot as plt
from detecto.utils import read_image

# %%
img = read_image('./imgs/cucumber/training/cucumber_10.jpg')
plt.imshow(img)
plt.show()

# %%
from detecto.core import Dataset

dataset = Dataset('./imgs/cucumber/training/')

# %%
from detecto.visualize import show_labeled_image

image, targets = dataset[0]
show_labeled_image(image, targets['boxes'], targets['labels'])

# %% [markdown]
# ## Create and train the model

# %%
from detecto.core import Model
from detecto.utils import read_image
from detecto.visualize import show_labeled_image

model = Model(['cucumber', 'onion', 'red_onion'])

# %%
# model.fit(dataset)
# Out:
# It looks like you're training your model on a CPU. Consider switching to a GPU; otherwise, this method can take hours upon hours or even days to finish. For more information, see https://detecto.readthedocs.io/en/latest/usage/quickstart.html#technical-requirements
# Epoch 1 of 10
# Begin iterating over training dataset
# 100%|██████████| 64/64 [12:15<00:00, 11.49s/it]
# Epoch 2 of 10
# Begin iterating over training dataset
# 100%|██████████| 64/64 [10:30<00:00,  9.85s/it]
# Epoch 3 of 10
# Begin iterating over training dataset
# 100%|██████████| 64/64 [10:00<00:00,  9.39s/it]
# Epoch 4 of 10
# Begin iterating over training dataset
# 100%|██████████| 64/64 [10:01<00:00,  9.40s/it]
# Epoch 5 of 10
# Begin iterating over training dataset
# 100%|██████████| 64/64 [10:00<00:00,  9.38s/it]
# Epoch 6 of 10
# Begin iterating over training dataset
# 100%|██████████| 64/64 [08:41<00:00,  8.14s/it]
# Epoch 7 of 10
# Begin iterating over training dataset
# ...

# %%
# After training
# model.save('contour_model.pth')

# %%
loaded_model = Model.load('contour_model.pth', ['cucumber', 'onion', 'red_onion'])

# %%
test_image = read_image('./imgs/cucumber/test/red_onion_contour_4.jpg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 test_image = read_image('./imgs/cucumber/test/red_onion_contour_4.jpg')
#
# File c:\code\ml och dl\lecture 220411\venv\lib\site-packages\detecto\utils.py:133, in read_image(path)
#     113 """Helper function that reads in an image as a
#     114 `NumPy <https://numpy.org/>`_ array. Equivalent to using
#     115 `OpenCV <https://docs.opencv.org/master/>`_'s cv2.imread
#    (...)
#     130     >>> plt.show()
#     131 """
#     132 if not os.path.isfile(path):
# --> 133     raise ValueError(f'Could not read image {path}')
#     135 image = cv2.imread(path)
#     137 try:
#
# ValueError: Could not read image ./imgs/cucumber/test/red_onion_contour_4.jpg

# %%
labels, boxes, scores = model.predict(test_image)

# %%
print('Labels:', labels)
print('Boxes:', boxes)
print('Scores', scores)
# Out:
# Labels: ['cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucumber', 'cucu
# ...

# %%
show_labeled_image(test_image, boxes, labels)

# %%
show_labeled_image(test_image, boxes[0], labels[0])
